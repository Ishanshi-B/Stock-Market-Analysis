# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# <center>*Copyright Pierian Data 2017*</center>
# <center>*For more information, visit us at www.pieriandata.com*</center>

# %% [markdown]
# # Stock Market Analysis Project
#
# ### Please Note: You are free to treat this as a full exercise, or just view the solutions video as a code along project. This project is meant to be pretty challenging as it will introduce a few new concepts through some hints!
#
# Welcome to your first capstone project! This project is meant to cap off the first half of the course, which mainly dealt with learning the libraries that we use in this course, the second half of the course will deal a lot more with quantitative trading techniques and platforms.
#
# We'll be analyzing stock data related to a few car companies, from Jan 1 2012 to Jan 1 2017. Keep in mind that this project is mainly just to practice your skills with matplotlib, pandas, and numpy. Don't infer financial trading advice from the analysis we do here!
#
# ### Part 0: Import
#
# ** Import the various libraries you will need-you can always just come back up here or import as you go along :) **

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# !pip install yfinance
# !pip install --upgrade yfinance
# !pip install --upgrade yfinance pandas_datareader
# Out:
# Requirement already satisfied: yfinance in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (0.2.41)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (2.32.2)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2024.7.4)
# Requirement already satisfied: yfinance in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (0.2.41)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (2.32.2)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2024.7.4)
# Requirement already satisfied: yfinance in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (0.2.41)
# Requirement already satisfied: pandas_datareader in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (0.10.0)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (2.32.2)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2024.7.4)

# %% [markdown]
# ____
# ## Part 1: Getting the Data
#
# ### Tesla Stock (Ticker: TSLA on the NASDAQ)
#
# **  *Note! Not everyone will be working on a computer that will give them open access to download the stock information using pandas_datareader (firewalls, admin permissions, etc...). Because of this, the csv file for the Tesla is provided in a data folder inside this folder. It is called Tesla_Stock.csv. Feel free to just use this with read_csv! **
#
# ** Use pandas_datareader to obtain the historical stock information for Tesla from Jan 1, 2012 to Jan 1, 2017.**

# %%
import datetime as dt
import yfinance as yf

# %%
import pandas_datareader as web

# %%
# Set the date range
start = dt.datetime(2012, 1, 1)
end = dt.datetime(2017, 1, 1)

# %%
ticker = ['TSLA']
# Fetch data for TSLA
try:
    data = yf.download(ticker, start=start, end=end)
    print(f"Successfully fetched data for {ticker}")
except Exception as e:
    print(f"Error fetching data for {ticker}: {e}")

# Format the DataFrame as per your requirement
df_formatted = data[['Open', 'High', 'Low', 'Close', 'Volume']]
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Successfully fetched data for ['TSLA']

# %%
# print("Formatted data:")
# print(df_formatted.head())
df_formatted
# Out:
#                  Open       High        Low      Close    Volume
# Date
# 2012-01-03   1.929333   1.966667   1.843333   1.872000  13921500
# 2012-01-04   1.880667   1.911333   1.833333   1.847333   9451500
# 2012-01-05   1.850667   1.862000   1.790000   1.808000  15082500
# 2012-01-06   1.813333   1.852667   1.760667   1.794000  14794500
# 2012-01-09   1.800000   1.832667   1.741333   1.816667  13455000
# ...               ...        ...        ...        ...       ...
# 2016-12-23  13.866667  14.230000  13.847333  14.222667  70057500
# 2016-12-27  14.325333  14.816667  14.294667  14.635333  88735500
# 2016-12-28  14.768667  14.920000  14.480000  14.649333  56737500
# 2016-12-29  14.570667  14.613333  14.274667  14.312000  60675000
# 2016-12-30  14.420000  14.500000  14.112000  14.246000  69639000
#
# [1258 rows x 5 columns]

# %%
tsla = pd.read_csv('/Users/ishan/Finance/Python-for-Finance-Repo-master/07-Stock-Market-Analysis-Capstone-Project/Tesla_Stock.csv', index_col=0,parse_dates=True)
tsla
# Out:
#               Open    High     Low   Close   Volume
# Date
# 2012-01-03   28.94   29.50   27.65   28.08   928052
# 2012-01-04   28.21   28.67   27.50   27.71   630036
# 2012-01-05   27.76   27.93   26.85   27.12  1005432
# 2012-01-06   27.20   27.79   26.41   26.89   687081
# 2012-01-09   27.00   27.49   26.12   27.25   896951
# ...            ...     ...     ...     ...      ...
# 2016-12-23  208.00  213.45  207.71  213.34  4670464
# 2016-12-27  214.88  222.25  214.42  219.53  5915732
# 2016-12-28  221.53  223.80  217.20  219.74  3782456
# 2016-12-29  218.56  219.20  214.12  214.68  4044968
# 2016-12-30  216.30  217.50  211.68  213.69  4642620
#
# [1258 rows x 5 columns]

# %% [markdown]
# ### Other Car Companies
#
# ** Repeat the same steps to grab data for Ford and GM (General Motors), **

# %%
ford = pd.read_csv('/Users/ishan/Finance/Python-for-Finance-Repo-master/07-Stock-Market-Analysis-Capstone-Project/Ford_Stock.csv', index_col=0,parse_dates=True)
ford
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2012-01-03  11.00  11.25  10.99  11.13  45709811
# 2012-01-04  11.15  11.53  11.07  11.30  79725188
# 2012-01-05  11.33  11.63  11.24  11.59  67877467
# 2012-01-06  11.74  11.80  11.52  11.71  59840605
# 2012-01-09  11.83  11.95  11.70  11.80  53981467
# ...           ...    ...    ...    ...       ...
# 2016-12-23  12.43  12.46  12.36  12.46  15621178
# 2016-12-27  12.43  12.51  12.36  12.39  19467440
# 2016-12-28  12.37  12.45  12.22  12.25  26875381
# 2016-12-29  12.25  12.31  12.22  12.23  19819081
# 2016-12-30  12.24  12.28  12.08  12.13  27405736
#
# [1258 rows x 5 columns]

# %%
ticker = ['F']
# Fetch data for TSLA
try:
    data_F = yf.download(ticker, start=start, end=end)
    print(f"Successfully fetched data for {ticker}")
except Exception as e:
    print(f"Error fetching data for {ticker}: {e}")

# Format the DataFrame as per your requirement
data_format_F = data[['Open', 'High', 'Low', 'Close', 'Volume']]
data_format_F.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Successfully fetched data for ['F']
#                 Open      High       Low     Close    Volume
# Date
# 2012-01-03  1.929333  1.966667  1.843333  1.872000  13921500
# 2012-01-04  1.880667  1.911333  1.833333  1.847333   9451500
# 2012-01-05  1.850667  1.862000  1.790000  1.808000  15082500
# 2012-01-06  1.813333  1.852667  1.760667  1.794000  14794500
# 2012-01-09  1.800000  1.832667  1.741333  1.816667  13455000

# %%
ticker = ['GM']
# Fetch data for TSLA
try:
    data_GM = yf.download(ticker, start=start, end=end)
    print(f"Successfully fetched data for {ticker}")
except Exception as e:
    print(f"Error fetching data for {ticker}: {e}")

# Format the DataFrame as per your requirement
data_format_GM = data[['Open', 'High', 'Low', 'Close', 'Volume']]
data_format_GM.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Successfully fetched data for ['GM']
#                 Open      High       Low     Close    Volume
# Date
# 2012-01-03  1.929333  1.966667  1.843333  1.872000  13921500
# 2012-01-04  1.880667  1.911333  1.833333  1.847333   9451500
# 2012-01-05  1.850667  1.862000  1.790000  1.808000  15082500
# 2012-01-06  1.813333  1.852667  1.760667  1.794000  14794500
# 2012-01-09  1.800000  1.832667  1.741333  1.816667  13455000

# %% [markdown]
# ## Part 2: Visualizing the Data
#
# ** Time to visualize the data. **
#
# ** Follow along and recreate the plots below according to the instructions and explanations. **

# %% [markdown]
# ____
#
# ** Recreate this linear plot of all the stocks' Open price ! Hint: For the legend, use label parameter and plt.legend()**

# %%
tsla['Open'].plot(label='Tesla', figsize=(16,8), title='Opening Prices')
data_GM['Open'].plot(label='General Motors')
data_F['Open'].plot(label= 'Ford')
plt.legend();

# %% [markdown]
# ____

# %% [markdown]
# ** Plot the Volume of stock traded each day.**

# %%
tsla['Volume'].plot(label='Tesla', figsize=(16,8), title='Volume Traded')
data_GM['Volume'].plot(label='General Motors')
data_F['Volume'].plot(label= 'Ford')
plt.legend();

# %% [markdown]
# ** Interesting, looks like Ford had a really big spike somewhere in late 2013. What was the date of this maximum trading volume for Ford?**
#
# **Bonus: What happened that day? **

# %%
ford['Volume'].idxmax()
# Out:
# Timestamp('2013-12-18 00:00:00')

# %%
ford['Open'].plot(figsize=(20,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ____

# %% [markdown]
# ** The Open Price Time Series Visualization makes Tesla look like its always been much more valuable as a company than GM and Ford. But to really understand this we would need to look at the total market cap of the company, not just the stock price. Unfortunately our current data doesn't have that information of total units of stock present. But what we can do as a simple calcualtion to try to represent total money traded would be to multply the Volume column by the Open price. Remember that this still isn't the actual Market Cap, its just a visual representation of the total amount of money being traded around using the time series. (e.g. 100 units of stock at \$10 each versus 100000 units of stock at $1 each)**

# %% [markdown]
# ** Create a new column for each dataframe called "Total Traded" which is the Open Price multiplied by the Volume Traded.**

# %%
tsla['Total Traded'] = tsla['Open']*tsla['Volume']
data_F['Total Traded'] = data_F['Open']*data_F['Volume']
data_GM['Total Traded'] = data_GM['Open']*data_GM['Volume']

# %% [markdown]
# ** Plot this "Total Traded" against the time index.**

# %%
tsla['Total Traded'].plot(label='Tesla', figsize=(16,8), title='Volume Traded')
data_GM['Total Traded'].plot(label='GM', figsize=(16,8), title='Volume Traded')
data_F['Total Traded'].plot(label='Ford', figsize=(16,8), title='Volume Traded')
plt.legend();

# %% [markdown]
# ** Interesting, looks like there was huge amount of money traded for Tesla somewhere in early 2014. What date was that and what happened? **

# %%
tsla['Total Traded'].idxmax()
# Out:
# Timestamp('2014-02-25 00:00:00')

# %% [markdown]
# ____

# %% [markdown]
# ** Let's practice plotting out some MA (Moving Averages). Plot out the MA50 and MA200 for GM. **

# %%
data_GM['MA50']= data_GM['Open'].rolling(50).mean()
data_GM['MA200'] = data_GM['Open'].rolling(200).mean()
data_GM[['Open','MA50', 'MA200']].plot(figsize=(16,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ______

# %% [markdown]
# ** Finally lets see if there is a relationship between these stocks, after all, they are all related to the car industry. We can see this easily through a scatter matrix plot. Import scatter_matrix from pandas.plotting and use it to create a scatter matrix plot of all the stocks'opening price. You may need to rearrange the columns into a new single dataframe. Hints and info can be found here: https://pandas.pydata.org/pandas-docs/stable/visualization.html#scatter-matrix-plot **

# %%
from pandas.plotting import scatter_matrix

# %%
car_comp = pd.concat([tsla['Open'],data_GM['Open'], data_F['Open']], axis=1)

# %%
car_comp.columns=['Tesla Open', 'Ford Open', 'GM Open']
car_comp.head()
# Out:
#             Tesla Open  Ford Open  GM Open
# Date
# 2012-01-03       28.94  20.830000    11.00
# 2012-01-04       28.21  21.049999    11.15
# 2012-01-05       27.76  21.100000    11.33
# 2012-01-06       27.20  22.260000    11.74
# 2012-01-09       27.00  23.200001    11.83

# %%
scatter_matrix(car_comp,figsize=(8,8), alpha=0.2, hist_kwds={'bins': 50})
# Out:
# array([[<Axes: xlabel='Tesla Open', ylabel='Tesla Open'>,
#         <Axes: xlabel='Ford Open', ylabel='Tesla Open'>,
#         <Axes: xlabel='GM Open', ylabel='Tesla Open'>],
#        [<Axes: xlabel='Tesla Open', ylabel='Ford Open'>,
#         <Axes: xlabel='Ford Open', ylabel='Ford Open'>,
#         <Axes: xlabel='GM Open', ylabel='Ford Open'>],
#        [<Axes: xlabel='Tesla Open', ylabel='GM Open'>,
#         <Axes: xlabel='Ford Open', ylabel='GM Open'>,
#         <Axes: xlabel='GM Open', ylabel='GM Open'>]], dtype=object)

# %% [markdown]
# _____
# ### Bonus Visualization Task! (Note: This is hard!)
# **Let's now create a candlestick chart! Watch the video if you get stuck on trying to recreate this visualization, there are quite a few steps involved!Refer to the video to understand how to interpret and read this chart. Hints: https://matplotlib.org/examples/pylab_examples/finance_demo.html**
#
# ** Create a CandleStick chart for Ford in January 2012 (too many dates won't look good for a candlestick chart)**

# %%
! pip install --upgrade mplfinance
# Out:
# Requirement already satisfied: mplfinance in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (0.12.10b0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from mplfinance) (3.8.4)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from mplfinance) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from matplotlib->mplfinance) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from matplotlib->mplfinance) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from matplotlib->mplfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from matplotlib->mplfinance) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from matplotlib->mplfinance) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from matplotlib->mplfinance) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from matplotlib->mplfinance) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from pandas->mplfinance) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from pandas->mplfinance) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/pyfinance/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)

# %%
from mpl_finance import candlestick_ohlc

from matplotlib.dates import DateFormatter, date2num, WeekdayLocator, DayLocator, MONDAY

# %%
ford_reset = data_F.loc['2012-01'].reset_index()

# %%
ford_reset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          20 non-null     datetime64[ns]
#  1   Open          20 non-null     float64
#  2   High          20 non-null     float64
#  3   Low           20 non-null     float64
#  4   Close         20 non-null     float64
#  5   Adj Close     20 non-null     float64
#  6   Volume        20 non-null     int64
#  7   Total Traded  20 non-null     float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 1.4 KB

# %%
ford_reset['dates_axis'] = ford_reset['Date'].apply(lambda date: date2num(date))

# %%
ford_reset.head()
# Out:
#         Date   Open   High    Low  Close  Adj Close    Volume  Total Traded  \
# 0 2012-01-03  11.00  11.25  10.99  11.13   6.329382  45709900  5.028089e+08
# 1 2012-01-04  11.15  11.53  11.07  11.30   6.426060  79725200  8.889359e+08
# 2 2012-01-05  11.33  11.63  11.24  11.59   6.590975  67877500  7.690521e+08
# 3 2012-01-06  11.74  11.80  11.52  11.71   6.659214  59840700  7.025298e+08
# 4 2012-01-09  11.83  11.95  11.70  11.80   6.710395  53981500  6.386011e+08
#
#    dates_axis
# 0     15342.0
# 1     15343.0
# 2     15344.0
# 3     15345.0
# 4     15348.0

# %%
list_of_cols = ['dates_axis', 'Open', 'High', 'Low', 'Close']
ford_values = [tuple(vals) for vals in ford_reset[list_of_cols].values]
ford_values
# Out:
# [(15342.0, 11.0, 11.25, 10.989999771118164, 11.130000114440918),
#  (15343.0,
#   11.149999618530273,
#   11.529999732971191,
#   11.069999694824219,
#   11.300000190734863),
#  (15344.0,
#   11.329999923706055,
#   11.630000114440918,
#   11.239999771118164,
#   11.59000015258789),
#  (15345.0,
#   11.739999771118164,
#   11.800000190734863,
#   11.520000457763672,
#   11.710000038146973),
#  (15348.0,
#   11.829999923706055,
#   11.949999809265137,
#   11.699999809265137,
#   11.800000190734863),
#  (15349.0, 12.0, 12.050000190734863, 11.630000114440918, 11.800000190734863),
#  (15350.0,
#   11.739999771118164,
#   12.180000305175781,
#   11.649999618530273,
#   12.069999694824219),
#  (15351.0,
#   12.15999984741211,
#   12.180000305175781,
#   11.890000343322754,
#   12.140000343322754),
#  (15352.0,
#   12.010000228881836,
#   12.079999923706055,
#   11.84000015258789,
#   12.039999961853027),
#  (15356.0,
#   12.199999809265137,
#   12.260000228881836,
#   11.960000038146973,
#   12.020000457763672),
#  (15357.0, 12.029999732971191, 12.369999885559082, 12.0, 12.34000015258789),
#  (15358.0,
#   12.479999542236328,
#   12.720000267028809,
#   12.430000305175781,
#   12.609999656677246),
#  (15359.0,
#   12.550000190734863,
#   12.640000343322754,
#   12.449999809265137,
#   12.59000015258789),
#  (15362.0,
#   12.6899995803833,
#   12.84000015258789,
#   12.550000190734863,
#   12.65999984741211),
#  (15363.0,
#   12.5600004196167,
#   12.859999656677246,
#   12.460000038146973,
#   12.819999694824219),
#  (15364.0,
#   12.800000190734863,
#   12.979999542236328,
#   12.699999809265137,
#   12.930000305175781),
#  (15365.0,
#   13.029999732971191,
#   13.050000190734863,
#   12.65999984741211,
#   12.789999961853027),
#  (15366.0,
#   11.960000038146973,
#   12.529999732971191,
#   11.789999961853027,
#   12.210000038146973),
#  (15369.0, 12.0600004196167, 12.4399995803833, 12.0, 12.289999961853027),
#  (15370.0,
#   12.470000267028809,
#   12.510000228881836,
#   12.199999809265137,
#   12.420000076293945)]

# %%
mondays = WeekdayLocator(MONDAY)        # major ticks on the mondays
alldays = DayLocator()              # minor ticks on the days
weekFormatter = DateFormatter('%b %d')  # e.g., Jan 12
dayFormatter = DateFormatter('%d')      # e.g., 12

# %%
fig, ax = plt.subplots()
fig.subplots_adjust(bottom=0.2)
ax.xaxis.set_major_locator(mondays)
ax.xaxis.set_minor_locator(alldays)
ax.xaxis.set_major_formatter(weekFormatter)
#ax.xaxis.set_minor_formatter(dayFormatter)

#plot_day_summary(ax, quotes, ticksize=3)
candlestick_ohlc(ax, ford_values, width=0.1, colorup='g', colordown='r')

ax.xaxis_date()

# %% [markdown]
# ____
# # Part 3: Basic Financial Analysis
#
# Now it is time to focus on a few key financial calculations. This will serve as your transition to the second half of the course. All you need to do is follow along with the instructions, this will mainly be an exercise in converting a mathematical equation or concept into code using python and pandas, something we will do often when working with quantiative data! If you feel very lost in this section, don't worry! Just go to the solutions lecture and treat it as a code-along lecture, use whatever style of learning works best for you!
#
# Let's begin!
# ____

# %% [markdown]
# ## Daily Percentage Change
# First we will begin by calculating the daily percentage change. Daily percentage change is defined by the following formula:

# %% [markdown]
# $ r_t = \frac{p_t}{p_{t-1}} -1$

# %% [markdown]
# This defines r_t (return at time t) as equal to the price at time t divided by the price at time t-1 (the previous day) minus 1. Basically this just informs you of your percent gain (or loss) if you bought the stock on day and then sold it the next day. While this isn't necessarily helpful for attempting to predict future values of the stock, its very helpful in analyzing the volatility of the stock. If daily returns have a wide distribution, the stock is more volatile from one day to the next. Let's calculate the percent returns and then plot them with a histogram, and decide which stock is the most stable!

# %% [markdown]
# ** Create a new column for each dataframe called returns. This column will be calculated from the Close price column. There are two ways to do this, either a simple calculation using the .shift() method that follows the formula above, or you can also use pandas' built in pct_change method. **

# %%
tsla['returns'] = (tsla['Close']/tsla['Close'].shift(1))-1

# %%
tsla['returns'] = tsla['Close'].pct_change(1)
tsla['returns']
# Out:
# Date
# 2012-01-03         NaN
# 2012-01-04   -0.013177
# 2012-01-05   -0.021292
# 2012-01-06   -0.008481
# 2012-01-09    0.013388
#                 ...
# 2016-12-23    0.023459
# 2016-12-27    0.029015
# 2016-12-28    0.000957
# 2016-12-29   -0.023027
# 2016-12-30   -0.004612
# Name: returns, Length: 1258, dtype: float64

# %%
data_F['returns'] = data_F['Close'].pct_change(1)
data_GM['returns'] = data_GM['Close'].pct_change(1)

# %%
tsla.head()
# Out:
#              Open   High    Low  Close   Volume  Total Traded   returns
# Date
# 2012-01-03  28.94  29.50  27.65  28.08   928052   26857824.88       NaN
# 2012-01-04  28.21  28.67  27.50  27.71   630036   17773315.56 -0.013177
# 2012-01-05  27.76  27.93  26.85  27.12  1005432   27910792.32 -0.021292
# 2012-01-06  27.20  27.79  26.41  26.89   687081   18688603.20 -0.008481
# 2012-01-09  27.00  27.49  26.12  27.25   896951   24217677.00  0.013388

# %%
data_F.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume  Total Traded  \
# Date
# 2012-01-03  11.00  11.25  10.99  11.13   6.329382  45709900  5.028089e+08
# 2012-01-04  11.15  11.53  11.07  11.30   6.426060  79725200  8.889359e+08
# 2012-01-05  11.33  11.63  11.24  11.59   6.590975  67877500  7.690521e+08
# 2012-01-06  11.74  11.80  11.52  11.71   6.659214  59840700  7.025298e+08
# 2012-01-09  11.83  11.95  11.70  11.80   6.710395  53981500  6.386011e+08
#
#              returns
# Date
# 2012-01-03       NaN
# 2012-01-04  0.015274
# 2012-01-05  0.025664
# 2012-01-06  0.010354
# 2012-01-09  0.007686

# %%
data_GM.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2012-01-03  20.830000  21.180000  20.750000  21.049999  15.935246   9321300
# 2012-01-04  21.049999  21.370001  20.750000  21.150000  16.010950   7856700
# 2012-01-05  21.100000  22.290001  20.959999  22.170000  16.783112  17880600
# 2012-01-06  22.260000  23.030001  22.240000  22.920000  17.350876  18234500
# 2012-01-09  23.200001  23.430000  22.700001  22.840000  17.290306  12084500
#
#             Total Traded  MA50  MA200   returns
# Date
# 2012-01-03  1.941627e+08   NaN    NaN       NaN
# 2012-01-04  1.653835e+08   NaN    NaN  0.004751
# 2012-01-05  3.772807e+08   NaN    NaN  0.048227
# 2012-01-06  4.059000e+08   NaN    NaN  0.033829
# 2012-01-09  2.803604e+08   NaN    NaN -0.003490

# %% [markdown]
# ** Now plot a histogram of each companies returns. Either do them separately, or stack them on top of each other. Which stock is the most "volatile"? (as judged by the variance in the daily returns we will discuss volatility in a lot more detail in future lectures.)**

# %%
data_F['returns'].hist(bins=100)
# Out:
# <Axes: >

# %%
data_GM['returns'].hist(bins=100)
# Out:
# <Axes: >

# %%
tsla['returns'].hist(bins=100)
# Out:
# <Axes: >

# %%
tsla['returns'].hist(bins=100, label= 'Tesla', figsize= (10,8) )
data_GM['returns'].hist(bins=100, label= 'GM', figsize= (10,8) )
data_F['returns'].hist(bins=100, label= 'Ford', figsize= (10,8) )
plt.legend()

# %% [markdown]
# ** Try also plotting a KDE instead of histograms for another view point. Which stock has the widest plot? **

# %%
tsla['returns'].plot(kind='kde', label='Tesla',figsize=(10,8) )
data_GM['returns'].plot(kind='kde', label='GM',figsize=(10,8) )
data_F['returns'].plot(kind='kde', label='Ford',figsize=(10,8) )
plt.legend()

# %% [markdown]
# ** Try also creating some box plots comparing the returns. **

# %%
box_df = pd.concat([tsla['returns'], data_F['returns'], data_GM['returns']], axis=1)
box_df.columns = ['Tesla Returns', 'Ford Returns', 'GM Returns' ]
box_df.plot(kind='box', figsize=(8,11))
# Out:
# <Axes: >

# %% [markdown]
# ## Comparing Daily Returns between Stocks
#
# ** Create a scatter matrix plot to see the correlation between each of the stocks daily returns. This helps answer the questions of how related the car companies are. Is Tesla begin treated more as a technology company rather than a car company by the market?**

# %%
scatter_matrix(box_df, figsize=(8,8), alpha=0.2, hist_kwds={'bins':100});

# %% [markdown]
# ** It looks like Ford and GM do have some sort of possible relationship, let's plot just these two against eachother in scatter plot to view this more closely!**

# %%
box_df.plot(kind='scatter', x='Ford Returns', y='GM Returns', alpha=0.5, figsize=(8,8));

# %% [markdown]
# ____
# ## Cumulative Daily Returns
#
# Great! Now we can see which stock was the most wide ranging in daily returns (you should have realized it was Tesla, our original stock price plot should have also made that obvious).
#
# With daily cumulative returns, the question we are trying to answer is the following, if I invested $1 in the company at the beginning of the time series, how much would is be worth today? This is different than just the stock price at the current day, because it will take into account the daily returns. Keep in mind, our simple calculation here won't take into account stocks that give back a dividend. Let's look at some simple examples:

# %% [markdown]
# Lets us say there is a stock 'ABC' that is being actively traded on an exchange. ABC has the following prices corresponding to the dates given

# %% [markdown]
#     Date                        Price
#     01/01/2018                   10
#     01/02/2018                   15
#     01/03/2018                   20
#     01/04/2018                   25

# %% [markdown]
# **Daily Return** : Daily return is the profit/loss made by the stock compared to the previous day. (This is what ew just calculated above). A value above one indicates profit, similarly a value below one indicates loss. It is also expressed in percentage to convey the information better. (When expressed as percentage, if the value is above 0, the stock had give you profit else loss). So for the above example the daily returns would be

# %% [markdown]
#     Date                         Daily Return                  %Daily Return
#     01/01/2018                 10/10 =  1                          -
#     01/02/2018                 15/10 =  3/2                       50%
#     01/03/2018                 20/15 =  4/3                       33%
#     01/04/2018                 25/20 =  5/4                       20%

# %% [markdown]
# **Cumulative Return**: While daily returns are useful, it doesn't give the investor a immediate insight into the gains he had made till date, especially if the stock is very volatile. Cumulative return is computed relative to the day investment is made.  If cumulative return is above one, you are making profits else you are in loss. So for the above example cumulative gains are as follows

# %% [markdown]
#     Date                       Cumulative Return         %Cumulative Return
#     01/01/2018                  10/10 =  1                         100 %
#     01/02/2018                  15/10 =  3/2                       150 %
#     01/03/2018                  20/10 =  2                         200 %
#     01/04/2018                  25/10 =  5/2                       250 %

# %% [markdown]
# The formula for a cumulative daily return is:
#
# $ i_i = (1+r_t) * i_{t-1} $
#
# Here we can see we are just multiplying our previous investment at i at t-1 by 1+our percent returns. Pandas makes this very simple to calculate with its cumprod() method. Using something in the following manner:
#
#     df[daily_cumulative_return] = ( 1 + df[pct_daily_return] ).cumprod()

# %% [markdown]
# ** Create a cumulative daily return column for each car company's dataframe.**

# %%
tsla['Cumulative Return'] = (1+ tsla['returns']).cumprod()
data_F['Cumulative Return'] = (1+ data_F['returns']).cumprod()
data_GM['Cumulative Return'] = (1+ data_GM['returns']).cumprod()

# %% [markdown]
# ** Now plot the Cumulative Return columns against the time series index. Which stock showed the highest return for a $1 invested? Which showed the lowest?**

# %%
tsla['Cumulative Return'].plot(label='Tesla', figsize=(16,8))
data_F['Cumulative Return'].plot(label='Ford')
data_GM['Cumulative Return'].plot(label='GM')
plt.legend()
#TSLA had the highest return

# %% [markdown]
# # Great Job!
#
# That is it for thsi very basic analysis, this concludes this half of the course, which focuses much more on learning the tools of the trade. The second half of the course is where we really dive into functionality designed for time series, quantitative analysis, algorithmic trading, and much more!
